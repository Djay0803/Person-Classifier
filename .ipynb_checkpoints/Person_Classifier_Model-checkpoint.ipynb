# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('C:/Users/lenovo/Desktop/PersonClassifier/model/test_images/2019-08-17-10-01-29-483.jpg')
img.shape
# Out:
# (1600, 900, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1600, 900)

# %%
gray
# Out:
# array([[ 88,  89, 100, ..., 208, 208, 209],
#        [100,  88, 104, ..., 208, 208, 209],
#        [ 99,  99,  87, ..., 208, 208, 209],
#        ...,
#        [ 59,  53,  48, ..., 135, 133, 136],
#        [ 57,  54,  46, ..., 148, 150, 150],
#        [ 55,  59,  52, ..., 152, 153, 154]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('C:/Users/lenovo/Desktop/PersonClassifier/model/opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/lenovo/Desktop/PersonClassifier/model/opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[227, 295, 498, 498]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (227, 295, 498, 498)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()

for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h,x:x+w]
    roi_color = face_img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        
plt.figure()
plt.imshow(face_img,cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color,cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,1.3,5)
    
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = img[y:y+h,x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('C:/Users/lenovo/Desktop/PersonClassifier/model/test_images/2019-08-17-10-01-29-483.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('C:/Users/lenovo/Desktop/PersonClassifier/model/test_images/2019-08-17-10-01-29-483.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('C:/Users/lenovo/Desktop/PersonClassifier/model/test_images/27978.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('C:/Users/lenovo/Desktop/PersonClassifier/model/test_images/27978.jpg')
print(cropped_image_no_2_eyes)
# Out:
# None

# %%
path_to_data = "C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset"
path_to_cr_data = "C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\"

# %%
import os
img_dirs = []

for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\dhananjay_prajapati',
#  'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\dharmesh_prajapati',
#  'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\mona_prajapati',
#  'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\rakesh_jaiswal',
#  'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\swati_pal']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "\\" + cropped_file_name
            
            cv2.imwrite(cropped_file_path,roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# dhananjay_prajapati
# Generating cropped images in folder:  C:\Users\lenovo\Desktop\PersonClassifier\model\dataset\cropped\dhananjay_prajapati
# dharmesh_prajapati
# Generating cropped images in folder:  C:\Users\lenovo\Desktop\PersonClassifier\model\dataset\cropped\dharmesh_prajapati
# mona_prajapati
# Generating cropped images in folder:  C:\Users\lenovo\Desktop\PersonClassifier\model\dataset\cropped\mona_prajapati
# rakesh_jaiswal
# Generating cropped images in folder:  C:\Users\lenovo\Desktop\PersonClassifier\model\dataset\cropped\rakesh_jaiswal
# swati_pal
# Generating cropped images in folder:  C:\Users\lenovo\Desktop\PersonClassifier\model\dataset\cropped\swati_pal

# %%
import numpy as np
import pywt
import cv2

def w2d(img,mode='haar',level=1):
    imArray = img
    
    #Datatype Conversions
    #convert to grayscale
    imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
    
    #convert to float
    imArray = np.float32(imArray)
    imArray /= 255;
    
    #compute coefficients
    coeffs = pywt.wavedec2(imArray,mode,level=level)
    
    #Process Coefficient
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0;
    
    #reconstruction
    imArray_H = pywt.waverec2(coeffs_H,mode);
    imArray_H *= 255;
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har,cmap = 'gray')

# %%
celebrity_file_names_dict
# Out:
# {'dhananjay_prajapati': ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati1.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati2.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati3.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati4.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati5.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati6.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati7.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati8.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati9.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati10.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati11.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati12.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati13.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati14.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati15.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati16.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati17.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati18.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati19.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati20.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati21.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati22.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati23.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati24.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati25.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati26.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati27.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati28.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati29.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati30.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati31.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati32.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati33.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati34.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati35.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati36.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati37.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati38.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati39.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati40.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati41.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati42.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati43.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati44.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati45.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati46.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati47.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati48.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati49.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati50.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dhananjay_prajapati\\dhananjay_prajapati51.png'],
#  'dharmesh_prajapati': ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati1.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati2.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati3.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati4.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati5.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati6.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati7.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati8.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati9.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati10.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati11.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati12.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati13.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati14.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati15.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati16.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati17.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati18.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati19.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati20.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati21.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati22.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati23.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati24.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati25.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati26.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati27.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati28.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati29.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\dharmesh_prajapati\\dharmesh_prajapati30.png'],
#  'mona_prajapati': ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati1.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati2.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati3.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati4.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati5.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati6.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati7.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati8.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati9.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati10.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati11.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati12.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati13.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati14.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati15.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati16.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati17.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati18.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati19.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati20.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati21.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati22.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati23.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati24.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati25.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati26.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati27.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati28.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati29.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\mona_prajapati\\mona_prajapati30.png'],
#  'rakesh_jaiswal': ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal1.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal2.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal3.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal4.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal5.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal6.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal7.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal8.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal9.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal10.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal11.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal12.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal13.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal14.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal15.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal16.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal17.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal18.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal19.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal20.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal21.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal22.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal23.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal24.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal25.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal26.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal27.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal28.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal29.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal30.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal31.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal32.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal33.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal34.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal35.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal36.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal37.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal38.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\rakesh_jaiswal\\rakesh_jaiswal39.png'],
#  'swati_pal': ['C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal1.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal2.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal3.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal4.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal5.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal6.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal7.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal8.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal9.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal10.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal11.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal12.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal13.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal14.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal15.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal16.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal17.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal18.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal19.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal20.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal21.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal22.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal23.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal24.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal25.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal26.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal27.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal28.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal29.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal30.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal31.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal32.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal33.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal34.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal35.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal36.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal37.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal38.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal39.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal40.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal41.png',
#   'C:\\Users\\lenovo\\Desktop\\PersonClassifier\\model\\dataset\\cropped\\swati_pal\\swati_pal42.png']}

# %%
class_dict = {}
count = 0

for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count += 1
class_dict
# Out:
# {'dhananjay_prajapati': 0,
#  'dharmesh_prajapati': 1,
#  'mona_prajapati': 2,
#  'rakesh_jaiswal': 3,
#  'swati_pal': 4}

# %%
x = []
y = []

for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        
        if img is None:
            continue
        
        scalled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har,(32,32))
        
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        
        x.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
len(x[0])
# Out:
# 4096

# %%
x = np.array(x).reshape(len(x),4096).astype(float)
x.shape
# Out:
# (130, 4096)

# %%
x[0]
# Out:
# array([ 89.,  81.,  92., ..., 230.,  19., 254.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=0)

pipe = Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel = 'rbf',C = 10))])
pipe.fit(x_train,y_train)
pipe.score(x_test,y_test)
# Out:
# 0.5757575757575758

# %%
len(x_test)
# Out:
# 33

# %%
print(classification_report(y_test,pipe.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.82      0.72        11
#            1       0.00      0.00      0.00         2
#            2       1.00      0.25      0.40         8
#            3       0.60      0.60      0.60         5
#            4       0.56      0.71      0.63         7
#
#     accuracy                           0.58        33
#    macro avg       0.56      0.48      0.47        33
# weighted avg       0.67      0.58      0.56        33

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm' : {
        'model' : svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc_C' : [1,10,100,1000],
            'svc_kernel' : ['rbf','linear']
        }
    },
    'random_forest' : {
        'model' : RandomForestClassifier(),
        'params' : {
            'randomforestclassifier_n_estimators' : [1,5,10]
        }
    },
    'logistic_regression' : {
        'model' : LogisticRegression(solver='liblinear',multi_class='auto'),
        'params' : {
            'logisticregression_C' : [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-71fb5ca3f46c> in <module>
#       5     pipe = make_pipeline(StandardScaler(), mp['model'])
#       6     clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
# ----> 7     clf.fit(x_train, y_train)
#       8     scores.append({
#       9         'model': algo,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     518             cloned_parameters[k] = clone(v, safe=False)
#     519
# --> 520         estimator = estimator.set_params(**cloned_parameters)
#     521
#     522     start_time = time.time()
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in set_params(self, **kwargs)
#     139         self
#     140         """
# --> 141         self._set_params('steps', **kwargs)
#     142         return self
#     143
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in _set_params(self, attr, **params)
#      51                 self._replace_estimator(attr, name, params.pop(name))
#      52         # 3. Step parameters and other initialisation arguments
# ---> 53         super().set_params(**params)
#      54         return self
#      55
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     247             key, delim, sub_key = key.partition('__')
#     248             if key not in valid_params:
# --> 249                 raise ValueError('Invalid parameter %s for estimator %s. '
#     250                                  'Check the list of available parameters '
#     251                                  'with `estimator.get_params().keys()`.' %
#
# ValueError: Invalid parameter svc_C for estimator Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto', probability=True))]). Check the list of available parameters with `estimator.get_params().keys()`.
